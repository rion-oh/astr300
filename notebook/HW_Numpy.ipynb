# %% [markdown]
# Python NumPy Homework
#
# numpy Math functions
# numpy Statistical functions

# %%
import numpy as np

# %% [markdown]
# Create an array called:
# my_array
#
# 350 evenly spaced point between 0 and 3$\pi$

# %%
my_array = np.linspace(0,3*np.pi,350)

my_array

# %% [markdown]
# Print out the first 5 values of
# my_array

# %%
my_array[:3]

# %% [markdown]
# Print out the last 5 values of
# my_array

# %%
my_array[-5:]

# %% [markdown]
# Write an expression to compute:
#
# $$
# \huge
# f(x) = 3\ e^{-x/3} \sin(\pi x)
# $$
# Where
# x
# =
# my_array
# Call
# f(x)
# :
# my_result

# %%
my_result=3*(np.exp(-my_array/3))*(np.sin(np.pi*(my_array)))

my_result

# %% [markdown]
# Print out the first 5 values of
# my_result

# %%
my_result[:5]

# %% [markdown]
# Print out the last 5 values of
# my_result

# %%
my_result[-5:]

# %% [markdown]
# How many values of
# my_result
# are greater than 0.0?

# %%
np.size(my_result[my_result>0.0])

# %% [markdown]
# What fraction of the values of
# my_result
# are greater than 0.0?

# %%
np.size(my_result[my_result>0.0])/np.size(my_result)

# %% [markdown]
# What is the
# Average
# of the values in
# my_result

# %%
np.average(my_result)

# %% [markdown]
# What is the
# Standard Deviation
# of the values in
# my_result

# %%
np.std(my_result)

# %% [markdown]
# What fraction of values of
# my_result
# are between (Ave - Std) and (Ave + Std)?

# %%
avg = np.average(my_result)
std = np.std(my_result)

np.size(my_result[(my_result > avg - std) & (my_result < avg + std)]) / np.size(my_result)

# %% [markdown]
# What is the maximum value of
# my_result
# ?

# %%
np.max(my_result)

# %% [markdown]
# At what value of
# my_array
# is
# my_result
# at its maximum?

# %%
my_array[np.argmax(my_result)]

# %% [markdown]
# Due Mon Jan 12 - 1 pm
#
# Rerun your notebook:
# Kernel -> Restart Kernal and Run All Cells
# Export notebook as .html:
# File -> Save and Export Notebook as -> HTML
# Upload
# .html
# file to Canvas
